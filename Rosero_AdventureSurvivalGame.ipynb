# %%
"""
Author: gabriela.rosero
"""

"""
DocString:
    
    A) Introduction:
    This is a survival trivia game. You will need to use your survival skills
    in order to pass the 3 rounds of the game. Each round will simulate 2 days
    with a total of 6 days in the wilderness.
    
    Round 1: Start a fire. Answer the question.
    Round 2: Choose a number to answer a random question about water tips.
    Round 3: Guess the word from the letter bank. 

    B) Known Bugs and/or Errors:
    The game continues even when the input is blank.

"""

from colorama import Fore
from time import sleep
import random as randint
from sys import exit 

##Defining introduciton of the game.## 

def start_game():
    
    print(f"""
    Hi there player! What is your name?\n""")

    
    name = input ('Name: ')
    
    #Welcomeing the user. Ask name before starting, create variable for name.##

    print (f"""\n
    Welcome,{Fore.MAGENTA}{name}{Fore.RESET}""")

    ##Adding a pause before introducing the game##   
    sleep (1) 

    
    ##Using fore.color formating to  assign a color to text##

    print(f"""
    You are about to play one of the most challenging treasure hunt 
    games. You will be given a map to the $5,000 treasure that is burried somewhere
    in the jungle. Most of the map pieces are locked and the only way to unlock 
    them to continue your journey is by testing your wilderness knowledge and skills.

    But before we begin, why dont you introduce yourself?

    """)
    input (prompt= f"""{Fore.GREEN}
    **Press ENTER to continue**{Fore.RESET}\n""")
    

    ##Variables for introduction of user##
    
    place = input('Where do you come from? \n')       
    animal = input('Name an animal that scares you the most \n')

    print (f"""{Fore.MAGENTA}
    Hi! My name is {name} and I come from {place}.I'm sure I'll make it through 
    the end as long as I dont see any {animal} on the way.So wish me luck!{Fore.MAGENTA}""")

   
    input (prompt= f"""\n{Fore.GREEN}
    **Press ENTER to continue**{Fore.RESET}\n""")

    
    print (f"""
    Great, best of luck for sure, {name}.""")

    sleep(2)

    print (f"""\n
    
    Now...
    
    \n""")

    sleep (2)

    rules = input (f"""{Fore.BLUE}
    Are you ready for the {Fore.RED}Xtreme Adventure {Fore.BLUE}
    game{Fore.RESET}? yes/no: """)
      
   
    #Starting nested conditions for the different answers of the first question
    #the answer a rules.lower function will be applied to avoid errors when
    #written with capital letters or a combination of capital and lower letter

    if rules.lower() == 'yes':
        print (f"""\n
    Alright, let the game start!\n\n""")

    else:
        print (f"""\n
    Well..

    Too bad so sad, there is no going back!""")
    
    input (prompt='Press to start game')

    print (f"{'*'*100}")
    
    day_1 ()
    
    
#Defining round one as day 1.##
#This first round will mainly have nested conditions to answer 1 question.## 
    
def day_1():
 
    
    print (f"""{Fore.BLUE}                                                  
                                        ROUND #1
                                                               {Fore.RESET}
    {'-'*95}
    
   
    Your first challenge will be to start a fire, but first you need to choose
    the correct package of tools. 
    
    {Fore.RED}
    To start a fire with the bow technique you will need:{Fore.RESET}
    
    a. Hardwood, dry leave, softwood
    b. Hardwood, softwood, supple green wood
    c. Softwood, dry leave, fire starter
    
    """)
    
    day1_1 = input ()
        
    if day1_1.lower() == 'a':
        print (f"""{Fore.RED}
    Thats not right! Try again{Fore.RESET}""")
       
        ##Pause before trying again. If not it can be seeing as a bug##
        sleep(2)
        
        ##Return to questin##
        day_1()
        
            
    elif day1_1.lower() == 'b':
        print (f"""{Fore.GREEN}
    Correct! You have now unlocked another piece of the map and built a fire 
    to keep you warm for the night!{Fore.RESET}""")
        
        input (prompt= f"""\n{Fore.GREEN}
    Press ENTER to Continue{Fore.RESET}""")
        
        ##Continue with game##
        day_2()
         
    else: 
        print (f"""{Fore.RED}
    Thats not right, try again!{Fore.RESET}""")
        
        
        sleep(2)
        
        #Return to question.##
        day_1()
         
        

#Defining round 2.##

def day_2():
 
    
    print (f"""{Fore.BLUE}                                                  
                                        ROUND #2
                                                                {Fore.RESET}
    {'-'*100}
    
    
    Its your third day in the wilderness and you need water. To unlock the 
    location of the nearest pond in the map you need to answer a random
    question.
    {Fore.RED}
    Type a number from 1 to 3 to get your question{Fore.RESET}
    
    """) 
    
    day2_1 = input ()
    
    ##Nested condition first leve##
    
    if day2_1.lower() == '1':
        print (f"""{Fore.RED}

        How much water must the body lose before death?{Fore.RESET}

        a. At least 25%
        b. Atleast 12%
        c. Atleast 15%
        """)
     
    ##While function for each question to limit the number of attempts##
        
        correct = "c"
        attempts = 2
        
        while attempts > 0:
            day2_2 = input()
        
            ##Nested condition under the first choice in question##
            if day2_2 == correct:
                    print (f"""{Fore.GREEN}
                    That's right! You can now go look for water with the help 
                    of the map!{Fore.RESET}""")
                    input (prompt = f"""{Fore.GREEN}\nPress ENTER to continue{Fore.RESET}""")
                    day_3()
                    

            elif day2_2 != correct:
                    print (f"""{Fore.RED}
                    Thats not right! Try again{Fore.RESET}""")
                    attempts -= 1
                    
                   

            else:
                    print (f"""{Fore.RED}
                    Thats not right! Try again{Fore.RESET}""")
                    attempts -=1
                    
        fail()             
            
            
    ##If answer is b## 
    
    elif day2_1 == '2':
        print (f"""{Fore.RED}
        If you need water and all that is available is salt water should you drink it?{Fore.RESET}

        a. Yes
        b. No 
        """)
    
    ##While function for second question to limit the number of attempts##   
        
        correct = "b"
        attempts = 3
        
        while attempts > 0:
            day2_3 = input()
    
            ##Nested condition under the first choice in question##
            if day2_3 != correct:
                    print (f"""{Fore.RED}
                    Wrong! Try again.{Fore.RESET}""")
                    attempts -=1
                    

            elif day2_3 == correct:
                    print (f"""{Fore.GREEN}
                    Correct! The body uses twice as much of its water to digest salt.
                    So you can get dyhadrated!

                    You have unlocked the next piece of the map.{Fore.RESET}""")
                    
                    day_3()
       
        fail()
    
    ##If its not a or b##
    
    elif day2_1=='3': 
        print (f"""{Fore.RED}
            When in a desert environment what should you do to conserve water{Fore.RESET}?

            a. Not eat
            b. Keep eyes and mouth closed
            c. Not walk at all
            """)
        
        correct = "a"
        attempts = 2
        
        while attempts > 0:
            day2_4 = input()
        
            ##Nested condition under the third choice in question##
            if day2_4 == 'a':
                    print (f"""{Fore.GREEN}
                    Good job! You keep moving on.{Fore.RESET}""")
                    day_3()

            elif day2_4 == 'b':
                    print (f"""{Fore.RED}
                    Not quite, try again.{Fore.RESET}""")
                    attempts -= 1
                    

            else:
                    print (f"""{Fore.RED}
                    Not quite, try again{Fore.RESET}""")
                    attempts -= 1
        

        fail()
        

def day_3(): 
    
    print (f"""{Fore.BLUE}                                                  
                                    ROUND #3
                                                                  {Fore.RESET}
    {'-'*100}
    
    
    You need one more piece in the map to get to the treasure. For this you will
    need to guess the word from the list of letters. 
    
          {Fore.RED}
         Guess the word                  
          {Fore.RESET}
    
    [ o, n, a, t, n, m, u, i]
    
            """) 
    
    correct = 'mountain'
    attempts = 2
        
    while attempts > 0:
        secretwrd = input(prompt= '')
           
        if secretwrd == correct:
            print (f"""{Fore.MAGENTA}
                
       __                                                                
  / ()  _         _,  ,_   _, _|_       |\  _, _|_ o  _         ,  ||
 |     / \_/|/|  / | /  | / |  |  |  |  |/ / |  |  | / \_/|/|  / \_||
  \___/\_/  | |_/\/|/   |/\/|_/|_/ \/|_/|_/\/|_/|_/|/\_/  | |_/ \/ oo
                  (|                                                 
                  
                  You got the last piece of the map
                      and found the treasure!!
                
              Great survival skills! See you next time!
              
                      <<Press Enter to EXIT>>
                                                                {Fore.RESET}
    """)
            
            
            exit()
            
        elif secretwrd != correct:
            print (f"{Fore.RED}Try again one more time{Fore.RESET}")
            attempts -= 1
    fail()
    
    
def fail():
    print(f""" 
 You have died from dehydration or food poisoning
    

                        .#&@@&/                     
                    @@@@                  .@@@@           
                @@                               @@       
             @@                                     @@    
           &@                                         @   
          @@                                           @@ 
         (@                                             @ 
         @.  &@                                     @@  @@
         @*  &@                                     @@  ,@
         &@   @                                     @   @@
          @,   @                                   @    @ 
           @.  @    @@@@@@@@@@       @@@@@@@@@@    @  .@  
            @@ @  @@@@@@@@@@@@       @@@@@@@@@@@@  @ @%   
              @@   @@@@@@@@@@         @@@@@@@@@@   &@     
              @     @@@@@@@             @@@@@@@     @     
              @        /       @@ @@       /        @     
              @@             .@@@ @@@              @@     
                @@@          @@@@ @@@@          @@@       
                  @@  @@      @@   @@      @@@ @@         
                   @@   @#               ,@ % @@          
                    @ @   @@%        ,@@@     @           
                   ,@  @ @   & & @ @ @ . @ @  @           
                    @  .#    # % @ @ @ .  &   @           
                    @.     (@@## @ @.@@.     %@           
                     @@                     @@            
                       @@                .@@              
                           #@@@@@@@@@@@.     

    
      Do you want to play again? yes/no
    """)
    
    
    answer_game = input (prompt =" ")
    
    if answer_game.lower() == "yes":
        start_game()
    
    else:
        answer_game.lower() == "no"
        print (f"""{Fore.BLUE}
       THANK YOU FOR PLAYING!!
        {Fore.RESET}""")
        exit()

day_3()
# Out:
#
#                                     ROUND #3
#
#     ----------------------------------------------------------------------------------------------------
#
#
#     You need one more piece in the map to get to the treasure. For this you will
#     need to guess the word from the list of letters.
#
#
#          Guess the word
#
#
#     [ o, n, a, t, n, m, u, i]
#
#
# jksnn
# Try again one more time
# mountain
#
#
#        __
#   / ()  _         _,  ,_   _, _|_       |\  _, _|_ o  _         ,  ||
#  |     / \_/|/|  / | /  | / |  |  |  |  |/ / |  |  | / \_/|/|  / \_||
#   \___/\_/  | |_/\/|/   |/\/|_/|_/ \/|_/|_/\/|_/|_/|/\_/  | |_/ \/ oo
#                   (|
#
#                   You got the last piece of the map
#                       and found the treasure!!
#
#               Great survival skills! See you next time!
#
#                       <<Press Enter to EXIT>>
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# ...
